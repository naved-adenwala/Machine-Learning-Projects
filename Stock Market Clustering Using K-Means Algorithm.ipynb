# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import datetime
from pandas_datareader import data
import seaborn as sns 
# %matplotlib inline

# %%
companies_dict = {
    'Amazon':'AMZN',
    'Apple':'AAPL',
    'Walgreen':'WBA',
    'Northrop Grumman':'NOC',
    'Boeing':'BA',
    'Lockheed Martin':'LMT',
    'McDonalds':'MCD',
    'Intel':'INTC',
    'IBM':'IBM',
    'Texas Instruments':'TXN',
    'MasterCard':'MA',
    'Microsoft':'MSFT',
    'General Electrics':'GE',
    'American Express':'AXP',
    'Pepsi':'PEP',
    'Coca Cola':'KO',
    'Johnson & Johnson':'JNJ',
    'Toyota':'TM',
    'Honda':'HMC',
    'Exxon':'XOM',
    'Chevron':'CVX',
    'Valero Energy':'VLO',
    'Ford':'F',
    'Bank of America':'BAC'}

# %%
start = "2015-04-25"
end =  "2020-04-25"

df = data.DataReader(list(companies_dict.values()),data_source="yahoo",start=start,end=end)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1260 entries, 2015-04-24 to 2020-04-24
# Columns: 144 entries, ('Adj Close', 'AMZN') to ('Volume', 'BAC')
# dtypes: float64(144)
# memory usage: 1.4 MB

# %%
df.head()
# Out:
# Attributes   Adj Close                                                \
# Symbols           AMZN       AAPL        WBA         NOC          BA
# Date
# 2015-04-24  445.100006  29.523201  69.871109  143.719742  130.596771
# 2015-04-27  438.559998  30.060265  69.984871  142.253967  130.068756
# 2015-04-28  429.309998  29.586649  69.952370  142.591553  129.813522
# 2015-04-29  429.369995  29.151548  68.725281  141.374466  128.616699
# 2015-04-30  421.779999  28.360666  67.392555  136.843796  126.143799
#
# Attributes                                                           ...  \
# Symbols            LMT        MCD       INTC         IBM        TXN  ...
# Date                                                                 ...
# 2015-04-24  161.734543  82.250534  26.317831  118.346268  45.265236  ...
# 2015-04-27  160.468002  80.334625  26.662388  119.008507  45.951702  ...
# 2015-04-28  160.616989  80.659500  27.088991  121.232109  45.843513  ...
# 2015-04-29  158.356949  80.817780  26.982346  121.566666  45.785271  ...
# 2015-04-30  154.474442  80.426270  26.703411  119.398865  45.111217  ...
#
# Attributes     Volume                                               \
# Symbols           PEP          KO         JNJ        TM        HMC
# Date
# 2015-04-24  5381700.0  11623300.0   6566900.0  277500.0   824800.0
# 2015-04-27  5348500.0  10044600.0   9113900.0  273000.0   557200.0
# 2015-04-28  5065900.0  12174800.0   7484600.0  421900.0  2455300.0
# 2015-04-29  4963600.0  11371400.0   8926200.0  282900.0  1481400.0
# 2015-04-30  6714400.0  12700800.0  10170600.0  246800.0   750000.0
#
# Attributes
# Symbols            XOM        CVX        VLO           F          BAC
# Date
# 2015-04-24   8405700.0  4995000.0  5277700.0  20293300.0   40766100.0
# 2015-04-27  10534600.0  4858700.0  8056400.0  34824900.0   73523400.0
# 2015-04-28   9633800.0  5321600.0  7905400.0  56634200.0   58080100.0
# 2015-04-29  12534100.0  5665800.0  6002600.0  35126900.0  134499400.0
# 2015-04-30  13947700.0  6666800.0  8067500.0  30269300.0   78313900.0
#
# [5 rows x 144 columns]

# %%
df.isnull().sum()
# Out:
# Attributes  Symbols
# Adj Close   AMZN       0
#             AAPL       0
#             WBA        0
#             NOC        0
#             BA         0
#                       ..
# Volume      XOM        0
#             CVX        0
#             VLO        0
#             F          0
#             BAC        0
# Length: 144, dtype: int64

# %%
stock_open = np.array(df["Open"]).T
stock_close = np.array(df["Close"]).T

change = stock_open - stock_close

# %%
for i in range(len(companies_dict)):
    print("Company:{} change {}".format(df["High"].columns[i],np.sum(change,1)[i]))
# Out:
# Company:AMZN change 160.47024536132812
# Company:AAPL change -45.97247505187988
# Company:WBA change 37.489990234375
# Company:NOC change -78.51982116699219
# Company:BA change 74.28045654296875
# Company:LMT change -45.6903076171875
# Company:MCD change -50.8701171875
# Company:INTC change -42.16000175476074
# Company:IBM change 11.233123779296875
# Company:TXN change -46.83992385864258
# Company:MA change -69.43009185791016
# Company:MSFT change -32.16990280151367
# Company:GE change 59.230506896972656
# Company:AXP change 8.069831848144531
# Company:PEP change -52.980125427246094
# Company:KO change -13.529964447021484
# Company:JNJ change -47.079856872558594
# Company:TM change 52.01002502441406
# Company:HMC change 21.430004119873047
# Company:XOM change 23.74008560180664
# Company:CVX change 21.46996307373047
# Company:VLO change 30.129920959472656
# Company:F change 14.950011730194092
# Company:BAC change -2.3599748611450195

# %%
plt.figure(figsize=(15,10))
plt.subplot(1,2,1)

plt.title('Company : Amazon',fontsize = 20)
plt.xlabel("Year")
plt.ylabel("Opening Price")
plt.plot(df["Open"]["AMZN"])


plt.subplot(1,2,2)
plt.title('Company : Apple',fontsize = 20)
plt.xlabel("Year")
plt.ylabel("Opening Price")
plt.plot(df["Open"]["AAPL"])

# %%
plt.figure(figsize = (20,10)) 
plt.subplot(1,2,1) 

plt.title('Company:Amazon',fontsize = 20)
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 20)
plt.xlabel('Date',fontsize = 15)
plt.ylabel('Opening price',fontsize = 15)
plt.plot(df['Open']['AMZN'])
plt.subplot(1,2,2) 

plt.title('Company:Apple',fontsize = 20)
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 20)
plt.xlabel('Date',fontsize = 15)
plt.ylabel('Opening price',fontsize = 15)
plt.plot(df['Open']['AAPL'])

# %%
plt.figure(figsize = (20,10)) # Adjusting figure size
plt.title('Company:Amazon',fontsize = 20)
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 20)
plt.xlabel('Date',fontsize = 20)
plt.ylabel('Price',fontsize = 20)
plt.plot(df.iloc[0:30]['Open']['AMZN'],label = 'Open') # Opening prices of first 30 days are plotted against date
plt.plot(df.iloc[0:30]['Close']['AMZN'],label = 'Close') # Closing prices of first 30 days are plotted against date
plt.legend(loc=(0.8,0.8), frameon=False,framealpha=1,prop={'size': 25}) # Properties of legend box

# %%
plt.figure(figsize = (20,8)) 
plt.title('Company:Amazon',fontsize = 20)
plt.xlabel('Date',fontsize = 20)
plt.ylabel('Change',fontsize = 20)
plt.plot(change[0][0:30])

# %%
plt.figure(figsize = (20,10)) 
plt.title('Company:Amazon',fontsize = 20)
plt.xlabel('Date',fontsize = 20)
plt.ylabel('Volume',fontsize = 20)
plt.plot(df['Volume']['AMZN'],label = 'Open')

# %%
plt.figure(figsize = (20,8)) 
ax1 = plt.subplot(1,2,1)
plt.title('Company:Amazon',fontsize = 20)
plt.xticks(fontsize = 18)
plt.yticks(fontsize = 20)
plt.xlabel('Date',fontsize = 20)
plt.ylabel('Movement',fontsize = 20)
plt.plot(change[0]) 
plt.subplot(1,2,2,sharey = ax1)
plt.title('Company:Apple',fontsize = 20)
plt.xticks(fontsize = 18)
plt.yticks(fontsize = 20)
plt.xlabel('Date',fontsize = 20)
plt.ylabel('Movement',fontsize = 20)
plt.plot(change[1])

# %%
from sklearn.preprocessing import Normalizer
normalizer = Normalizer() # Define a Normalizer
norm_movements = normalizer.fit_transform(change) # Fit and transform

# %%
print(norm_movements.min())
print(norm_movements.max())
print(norm_movements.mean())
# Out:
# -0.2655260562450729
# 0.3350859880144041
# 3.7305170970841864e-05

# %%
plt.figure(figsize = (20,8)) 
ax1 = plt.subplot(1,2,1)
plt.title('Company:Amazon',fontsize = 20)
plt.xticks(fontsize = 18)
plt.yticks(fontsize = 20)
plt.xlabel('Date',fontsize = 20)
plt.ylabel('Movement',fontsize = 20)
plt.plot(norm_movements[0]) 
plt.subplot(1,2,2,sharey = ax1)
plt.title('Company:Apple',fontsize = 20)
plt.xticks(fontsize = 18)
plt.yticks(fontsize = 20)
plt.xlabel('Date',fontsize = 20)
plt.ylabel('Movement',fontsize = 20)
plt.plot(norm_movements[1])

# %%
from sklearn.pipeline import make_pipeline
from sklearn.cluster import KMeans

# %%
# Define a normalizer
normalizer = Normalizer()
# Create Kmeans model
kmeans = KMeans(n_clusters = 10,max_iter = 1000)
# Make a pipeline chaining normalizer and kmeans
pipeline = make_pipeline(normalizer,kmeans)
# Fit pipeline to daily stock movements
pipeline.fit(change)
predictions = pipeline.predict(change)
pd.DataFrame({"Labels":predictions,"Company":list(companies_dict)}).sort_values(by="Labels",axis=0)
# Out:
#     Labels            Company
# 3        0   Northrop Grumman
# 5        0    Lockheed Martin
# 23       1    Bank of America
# 18       1              Honda
# 8        1                IBM
# 17       1             Toyota
# 22       1               Ford
# 13       1   American Express
# 21       2      Valero Energy
# 20       2            Chevron
# 19       2              Exxon
# 7        3              Intel
# 9        3  Texas Instruments
# 0        4             Amazon
# 10       4         MasterCard
# 1        4              Apple
# 11       4          Microsoft
# 2        5           Walgreen
# 4        6             Boeing
# 12       7  General Electrics
# 14       8              Pepsi
# 15       8          Coca Cola
# 16       8  Johnson & Johnson
# 6        9          McDonalds

# %%
predictions
# Out:
# array([0, 0, 9, 3, 4, 3, 7, 0, 2, 0, 0, 0, 8, 1, 6, 6, 6, 2, 2, 5, 5, 5,
#        2, 1])

# %%
# Out:
#     Labels            Company
# 0        0             Amazon
# 10       0         MasterCard
# 9        0  Texas Instruments
# 7        0              Intel
# 11       0          Microsoft
# 1        0              Apple
# 23       1    Bank of America
# 13       1   American Express
# 18       2              Honda
# 17       2             Toyota
# 8        2                IBM
# 22       2               Ford
# 5        3    Lockheed Martin
# 3        3   Northrop Grumman
# 4        4             Boeing
# 19       5              Exxon
# 20       5            Chevron
# 21       5      Valero Energy
# 15       6          Coca Cola
# 16       6  Johnson & Johnson
# 14       6              Pepsi
# 6        7          McDonalds
# 12       8  General Electrics
# 2        9           Walgreen

# %%
from sklearn.decomposition import PCA
# Define a normalizer
normalizer = Normalizer()
#PCA model
pca = PCA(n_components=2)

# Create Kmeans model
kmeans = KMeans(n_clusters = 10,max_iter = 1000)
# Make a pipeline chaining normalizer and kmeans
pipeline = make_pipeline(normalizer,pca,kmeans)
# Fit pipeline to daily stock movements
pipeline.fit(change)
predictions = pipeline.predict(change)

# %%
pd.DataFrame({"Labels":predictions,"Company":list(companies_dict)}).sort_values(by="Labels",axis=0)
# Out:
#     Labels            Company
# 2        0           Walgreen
# 6        0          McDonalds
# 18       1              Honda
# 17       1             Toyota
# 8        1                IBM
# 7        2              Intel
# 9        2  Texas Instruments
# 15       3          Coca Cola
# 16       3  Johnson & Johnson
# 20       4            Chevron
# 22       4               Ford
# 12       4  General Electrics
# 19       4              Exxon
# 3        5   Northrop Grumman
# 5        5    Lockheed Martin
# 21       6      Valero Energy
# 23       6    Bank of America
# 4        7             Boeing
# 13       7   American Express
# 0        8             Amazon
# 10       8         MasterCard
# 1        8              Apple
# 11       8          Microsoft
# 14       9              Pepsi
